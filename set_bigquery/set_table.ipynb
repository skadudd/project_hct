# %%
from google.cloud import bigquery
from google.cloud.bigquery import job
import pandas as pd
import os
from tqdm import tqdm
import pandas as pd
PROJCECT = 'ballosodeuk'
bq = bigquery.Client(project=PROJCECT)

# %%
client = bigquery.Client()
# Out:
# c:\Users\Owner\miniconda3\envs\pymc\lib\site-packages\google\auth\_default.py:76: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)

# %%
table_id = "ballosodeuk.airbridge_lake.web_2024"
schema = [
    bigquery.SchemaField("User_ID", "STRING"),
    bigquery.SchemaField("Hashed_User_ID", "STRING"),
    bigquery.SchemaField("User_Email", "STRING"),
    bigquery.SchemaField("Hashed_User_Email", "STRING"),
    bigquery.SchemaField("User_Phone", "STRING"),
    bigquery.SchemaField("Hashed_User_Phone", "STRING"),
    bigquery.SchemaField("User_ID_Alias", "STRING"),
    bigquery.SchemaField("Custom_User_Properties", "STRING"),
    bigquery.SchemaField("Device_ID_Alias", "STRING"),
    bigquery.SchemaField("Device_Model", "STRING"),
    bigquery.SchemaField("Device_Type", "STRING"),
    bigquery.SchemaField("Platform", "STRING"),
    bigquery.SchemaField("Manufacturer", "STRING"),
    bigquery.SchemaField("OS_Name", "STRING"),
    bigquery.SchemaField("OS_Version", "STRING"),
    bigquery.SchemaField("Client_IP", "STRING"),
    bigquery.SchemaField("Client_IP_Country", "STRING"),
    bigquery.SchemaField("Client_IP_Country_Code", "STRING"),
    bigquery.SchemaField("Client_IP_Subdivision", "STRING"),
    bigquery.SchemaField("Client_IP_City", "STRING"),
    bigquery.SchemaField("Client_IP_Cloud_Provider", "STRING"),
    bigquery.SchemaField("Client_IP_Cloud_Provider_Service", "STRING"),
    bigquery.SchemaField("Cookie_ID", "STRING"),
    bigquery.SchemaField("Browser_Name", "STRING"),
    bigquery.SchemaField("Browser_Version", "STRING"),
    bigquery.SchemaField("Browser_User_Agent", "STRING"),
    bigquery.SchemaField("Browser_Timezone_Offset", "NUMERIC"),
    bigquery.SchemaField("Airbridge_App_Name", "STRING"),
    bigquery.SchemaField("Event_Category", "STRING"),
    bigquery.SchemaField("Event_Action", "STRING"),
    bigquery.SchemaField("Event_Label", "STRING"),
    bigquery.SchemaField("Event_Value", "FLOAT64"),
    bigquery.SchemaField("Event_Value__Original_", "FLOAT64"),
    bigquery.SchemaField("Event_Datetime", "STRING"),
    bigquery.SchemaField("Event_Datetime_GMT", "STRING"),
    bigquery.SchemaField("Event_Timestamp", "NUMERIC"),
    bigquery.SchemaField("Event_Sent_Timestamp", "NUMERIC"),
    bigquery.SchemaField("Event_Received_Timestamp", "NUMERIC"),
    bigquery.SchemaField("Semantic_Event_Properties", "STRING"),
    bigquery.SchemaField("Total_Revenue", "FLOAT64"),
    bigquery.SchemaField("Total_Revenue__Original_", "FLOAT64"),
    bigquery.SchemaField("Currency", "STRING"),
    bigquery.SchemaField("Currency__Original_", "STRING"),
    bigquery.SchemaField("Product_List", "STRING"),
    bigquery.SchemaField("Product_ID", "STRING"),
    bigquery.SchemaField("Product_Name", "STRING"),
    bigquery.SchemaField("Product_Price", "FLOAT64"),
    bigquery.SchemaField("Product_Quantity", "INT64"),
    bigquery.SchemaField("Product_Currency", "STRING"),
    bigquery.SchemaField("Product_Position", "INT64"),
    bigquery.SchemaField("Product_Category_ID", "STRING"),
    bigquery.SchemaField("Product_Category_Name", "STRING"),
    bigquery.SchemaField("Product_Brand_ID", "STRING"),
    bigquery.SchemaField("Product_Brand_Name", "STRING"),
    bigquery.SchemaField("Period", "STRING"),
    bigquery.SchemaField("Is_Renewal_Event", "BOOL"),
    bigquery.SchemaField("Renewal_Count", "NUMERIC"),
    bigquery.SchemaField("Product_List_ID", "STRING"),
    bigquery.SchemaField("Cart_ID", "STRING"),
    bigquery.SchemaField("Transaction_ID", "STRING"),
    bigquery.SchemaField("Transaction_Type", "STRING"),
    bigquery.SchemaField("Transaction_Paired_Event_Category", "STRING"),
    bigquery.SchemaField("Transaction_Paired_Event_Timestamp", "NUMERIC"),
    bigquery.SchemaField("Total_Quantity", "NUMERIC"),
    bigquery.SchemaField("Search_Query", "STRING"),
    bigquery.SchemaField("In_App_Purchased", "BOOL"),
    bigquery.SchemaField("Contribution_Margin", "FLOAT64"),
    bigquery.SchemaField("Contribution_Margin__Original_", "FLOAT64"),
    bigquery.SchemaField("List_ID", "STRING"),
    bigquery.SchemaField("Rate_ID", "STRING"),
    bigquery.SchemaField("Rate", "FLOAT64"),
    bigquery.SchemaField("Max_Rate", "FLOAT64"),
    bigquery.SchemaField("Achievement_ID", "STRING"),
    bigquery.SchemaField("Shared_Channel", "STRING"),
    bigquery.SchemaField("Date_Time", "STRING"),
    bigquery.SchemaField("Description", "STRING"),
    bigquery.SchemaField("Is_Revenue_Event", "BOOL"),
    bigquery.SchemaField("Place", "STRING"),
    bigquery.SchemaField("Schedule_ID", "STRING"),
    bigquery.SchemaField("Type", "STRING"),
    bigquery.SchemaField("Level", "STRING"),
    bigquery.SchemaField("Score", "FLOAT64"),
    bigquery.SchemaField("Is_First_Event_per_User_ID_By_Client", "BOOL"),
    bigquery.SchemaField("Custom_Event_Properties", "STRING"),
    bigquery.SchemaField("Event_Source", "STRING"),
    bigquery.SchemaField("Event_Name", "STRING"),
    bigquery.SchemaField("Event_Type", "STRING"),
    bigquery.SchemaField("Event_ID", "STRING"),
    bigquery.SchemaField("Is_First_Event_per_User_ID", "BOOL"),
    bigquery.SchemaField("Is_First_Event_per_User_ID_By", "STRING"),
    bigquery.SchemaField("Is_First_Event_per_User_ID_By_Airbridge", "BOOL"),
    bigquery.SchemaField("Request_URL", "STRING"),
    bigquery.SchemaField("Target_URL", "STRING"),
    bigquery.SchemaField("Browser_Referrer", "STRING"),
    bigquery.SchemaField("Browser_Referrer_Host", "STRING"),
    bigquery.SchemaField("Session_ID", "STRING"),
    bigquery.SchemaField("Session_Start_Timestamp", "NUMERIC"),
    bigquery.SchemaField("Session_Timeout", "NUMERIC"),
    bigquery.SchemaField("Channel", "STRING"),
    bigquery.SchemaField("Campaign", "STRING"),
    bigquery.SchemaField("Ad_Group", "STRING"),
    bigquery.SchemaField("Ad_Creative", "STRING"),
    bigquery.SchemaField("Content", "STRING"),
    bigquery.SchemaField("Term", "STRING"),
    bigquery.SchemaField("Sub_Publisher", "STRING"),
    bigquery.SchemaField("Sub_Sub_Publisher_1", "STRING"),
    bigquery.SchemaField("Sub_Sub_Publisher_2", "STRING"),
    bigquery.SchemaField("Sub_Sub_Publisher_3", "STRING"),
    bigquery.SchemaField("Campaign_Type", "STRING"),
    bigquery.SchemaField("Campaign_ID", "STRING"),
    bigquery.SchemaField("Ad_Group_ID", "STRING"),
    bigquery.SchemaField("Ad_Creative_ID", "STRING"),
    bigquery.SchemaField("Term_ID", "STRING"),
    bigquery.SchemaField("CTA_Param_1", "STRING"),
    bigquery.SchemaField("CTA_Param_2", "STRING"),
    bigquery.SchemaField("CTA_Param_3", "STRING"),
    bigquery.SchemaField("Click_ID", "STRING"),
    bigquery.SchemaField("Channel_Type", "STRING"),
    bigquery.SchemaField("Touchpoint_Generation_Type", "STRING"),
    bigquery.SchemaField("Is_Re_engagement", "BOOL"),
    bigquery.SchemaField("Tracking_Link_ID", "STRING"),
    bigquery.SchemaField("Campaign_Short_ID", "STRING"),
    bigquery.SchemaField("Email_of_the_Tracking_Link_Creator", "STRING"),
    bigquery.SchemaField("Authority_of_the_Tracking_Link_Creator", "STRING"),
    bigquery.SchemaField("Agency_of_the_Tracking_Link_Creator", "STRING"),
    bigquery.SchemaField("Agency_ID_of_the_Tracking_Link_Creator", "NUMERIC"),
    bigquery.SchemaField("Airbridge_SDK_Version", "STRING"),
    bigquery.SchemaField("Event_Date", "DATE"),
    bigquery.SchemaField("Event_Date_GMT", "STRING")
]

table = bigquery.Table(table_id, schema=schema)
table = client.create_table(table)
